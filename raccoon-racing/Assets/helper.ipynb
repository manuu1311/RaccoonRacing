# %%
from PIL import Image
import os
from pathlib import Path

# %%
# Folder containing PNG images
folder_name = "Animations\CharSelection\sprites\DefineSprite_578_UIOverScreen"

# Output size
TARGET_SIZE = (500, 500)

folder = Path(folder_name)

for image_path in folder.glob("*.png"):
    with Image.open(image_path) as img:
        width, height = img.size

        # Coordinates for centered 500x500 crop
        top=730-250
        left=500-250
        right=left+TARGET_SIZE[0]
        bottom=top+TARGET_SIZE[1]

        # Crop ONLY the central 500x500 region
        cropped = img.crop((left, top, right, bottom))

        # Save (overwrite original)
        cropped.save(image_path)

        print(f"Cropped: {image_path}")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\emanu\AppData\Local\Temp\ipykernel_25296\2937879217.py:2: SyntaxWarning: invalid escape sequence '\C'
#   folder_name = "Animations\CharSelection\sprites\DefineSprite_578_UIOverScreen"
# Cropped: Animations\CharSelection\sprites\DefineSprite_578_UIOverScreen\1.png
# Cropped: Animations\CharSelection\sprites\DefineSprite_578_UIOverScreen\10.png
# Cropped: Animations\CharSelection\sprites\DefineSprite_578_UIOverScreen\11.png
# Cropped: Animations\CharSelection\sprites\DefineSprite_578_UIOverScreen\12.png
# Cropped: Animations\CharSelection\sprites\DefineSprite_578_UIOverScreen\13.png
# Cropped: Animations\CharSelection\sprites\DefineSprite_578_UIOverScreen\14.png
# Cropped: Animations\CharSelection\sprites\DefineSprite_578_UIOverScreen\15.png
# Cropped: Animations\CharSelection\sprites\DefineSprite_578_UIOverScreen\16.png
# ...

# %%
import matplotlib.pyplot as plt

folder_name = "Animations\CharSelection\sprites\DefineSprite_578_UIOverScreen"
img=Image.open(folder_name+'//5.png').convert("RGBA")
left=510
top=605
plt.imshow(img)
plt.plot(500,730,marker='x',markersize=10)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\C'
# <>:3: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\emanu\AppData\Local\Temp\ipykernel_25296\3660609145.py:3: SyntaxWarning: invalid escape sequence '\C'
#   folder_name = "Animations\CharSelection\sprites\DefineSprite_578_UIOverScreen"

# %%
img
# Out:
# <PIL.Image.Image image mode=RGBA size=985x1148>
